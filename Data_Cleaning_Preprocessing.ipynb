# %%
import pandas as pd 
import numpy as np

# %%
### Load in the data 
df = pd.read_csv("aggregated.csv")

# %%
## quick view of the data 
df.head()
# Out:
#    MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  FL_NUM ORIGIN  \
# 0    2.0          6.0  2017-02-25             B6    28.0    MCO
# 1    2.0          7.0  2017-02-26             B6    28.0    MCO
# 2    2.0          1.0  2017-02-27             B6    28.0    MCO
# 3    2.0          2.0  2017-02-28             B6    28.0    MCO
# 4    2.0          3.0  2017-02-01             B6    33.0    BTV
#
#   ORIGIN_CITY_NAME DEST DEST_CITY_NAME  CRS_DEP_TIME  ARR_DEL15  \
# 0      Orlando, FL  EWR     Newark, NJ        1000.0        0.0
# 1      Orlando, FL  EWR     Newark, NJ         739.0        0.0
# 2      Orlando, FL  EWR     Newark, NJ        1028.0        0.0
# 3      Orlando, FL  EWR     Newark, NJ         739.0        0.0
# 4   Burlington, VT  JFK   New York, NY        1907.0        0.0
#
#    CRS_ELAPSED_TIME  DISTANCE  Unnamed: 13
# 0             156.0     937.0          NaN
# 1             153.0     937.0          NaN
# 2             158.0     937.0          NaN
# 3             153.0     937.0          NaN
# 4              90.0     266.0          NaN

# %%
## Before encoding or classifying anything, lets first look for null values 
df.isna().sum()
# Out:
# MONTH                     0
# DAY_OF_WEEK               0
# FL_DATE                   0
# UNIQUE_CARRIER            0
# FL_NUM                    0
# ORIGIN                    0
# ORIGIN_CITY_NAME          0
# DEST                      0
# DEST_CITY_NAME            0
# CRS_DEP_TIME              0
# ARR_DEL15             71020
# CRS_ELAPSED_TIME         10
# DISTANCE                  0
# Unnamed: 13         5129354
# dtype: int64

# %%
### Unnamed: 13 is always null and therefore should be dropped 
df = df.drop(columns=['Unnamed: 13'])

# %%
### Destination city name is equivalently labelled w/ the Dest column so we can just one of these features 
### Same for origin city

# %%
df = df.drop(columns=["ORIGIN_CITY_NAME", "DEST_CITY_NAME"])

# %%
df.head()
# Out:
#    MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  FL_NUM ORIGIN DEST  \
# 0    2.0          6.0  2017-02-25             B6    28.0    MCO  EWR
# 1    2.0          7.0  2017-02-26             B6    28.0    MCO  EWR
# 2    2.0          1.0  2017-02-27             B6    28.0    MCO  EWR
# 3    2.0          2.0  2017-02-28             B6    28.0    MCO  EWR
# 4    2.0          3.0  2017-02-01             B6    33.0    BTV  JFK
#
#    CRS_DEP_TIME  ARR_DEL15  CRS_ELAPSED_TIME  DISTANCE
# 0        1000.0        0.0             156.0     937.0
# 1         739.0        0.0             153.0     937.0
# 2        1028.0        0.0             158.0     937.0
# 3         739.0        0.0             153.0     937.0
# 4        1907.0        0.0              90.0     266.0

# %%
df.head(100)
# Out:
#     MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  FL_NUM ORIGIN DEST  \
# 0     2.0          6.0  2017-02-25             B6    28.0    MCO  EWR
# 1     2.0          7.0  2017-02-26             B6    28.0    MCO  EWR
# 2     2.0          1.0  2017-02-27             B6    28.0    MCO  EWR
# 3     2.0          2.0  2017-02-28             B6    28.0    MCO  EWR
# 4     2.0          3.0  2017-02-01             B6    33.0    BTV  JFK
# ..    ...          ...         ...            ...     ...    ...  ...
# 95    2.0          5.0  2017-02-10             B6    43.0    RNO  LGB
# 96    2.0          6.0  2017-02-11             B6    43.0    RNO  LGB
# 97    2.0          7.0  2017-02-12             B6    43.0    RNO  LGB
# 98    2.0          1.0  2017-02-13             B6    43.0    RNO  LGB
# 99    2.0          2.0  2017-02-14             B6    43.0    RNO  LGB
#
#     CRS_DEP_TIME  ARR_DEL15  CRS_ELAPSED_TIME  DISTANCE
# 0         1000.0        0.0             156.0     937.0
# 1          739.0        0.0             153.0     937.0
# 2         1028.0        0.0             158.0     937.0
# 3          739.0        0.0             153.0     937.0
# 4         1907.0        0.0              90.0     266.0
# ..           ...        ...               ...       ...
# 95        1120.0        0.0              81.0     402.0
# 96        1120.0        0.0              81.0     402.0
# 97        1120.0        0.0              81.0     402.0
# 98        1120.0        0.0              81.0     402.0
# 99        1120.0        0.0              81.0     402.0
#
# [100 rows x 11 columns]

# %%
3
